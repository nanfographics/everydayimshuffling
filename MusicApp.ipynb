# %% [markdown]
# ## Ananya's Music App

# %% [markdown]
# Objective: An app where users can specify what they are in the mood for and the app generates a Spotify playlist (max 15 songs) based on the user's top tracks + top releases from their favorite artists input.
#
# The user will be asked to make selections either from a list of options or on a scale (1-5) for the following:
# <ul>
#     <li><b>What mood are you in?</b> - Users can choose from 'Good Mood' or 'Bad Mood' [Valence] </li>
#     <li><b>Do you want to dance?</b> - Scale of 1-5 (1: no dancing, 5 very dancing) [Danceability]</li>
#     <li><b>What activity best describes the scene?</b> - Selection: Solo Chill, Hanging with Friends, Social Gathering, Party, Rager [Energy] </li>
#     <li><b>What genre are you interested in?</b> - [TBD; will be selection based]

# %% [markdown]
# ## Installations, Imports, & Credentials

# %%
#Install necessary Libraries
# pip install spotipy
# pip install streamlit

# %%
#Needed to run Streamlit app in their cloud service
#pip freeze > requirements.txt

# %%
#Imports
import os
import pandas as pd
import streamlit as st
from collections import Counter
from spotipy import SpotifyException
import time
import requests
from IPython.display import display, Markdown
import requests

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth

# %%
#Set Environment Variables to prevent Harcoding adn Retrieve with the below code
# client_id = os.getenv('SPOTIPY_CLIENT_ID')
# client_secret = os.getenv('SPOTIPY_CLIENT_SECRET')

# %%
port = int(os.environ.get('PORT', 9000))
redirect_uri = f'http://localhost:{port}/callback'

#Hardcoded
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id='<INSERT ID>',
                                               client_secret='<INSERT SECRET>',
                                               redirect_uri=redirect_uri,
                                               scope='user-read-private user-top-read playlist-modify-private'))

# %% [markdown]
# ## Defining a Universe of Tracks

# %% [markdown]
# First, we will define the scope of our universe. The tracks we will use to generate playlists will be a user's top 50 most listened to songs in the 'medium term' + top 10 songs released by artists in their top 50 (if not already in their list).

# %% [markdown]
# ### Retrieving a user's top 50 tracks

# %%
#Current User Data - this will launch a window that will prompt you to log in to Spotify 
#and you should copy/paste the URL you are directed to in the box that appears below
user = sp.current_user()
user
# Out:
# {'display_name': 'Ananya Tinaikar',
#  'external_urls': {'spotify': 'https://open.spotify.com/user/1275022654'},
#  'href': 'https://api.spotify.com/v1/users/1275022654',
#  'id': '1275022654',
#  'images': [],
#  'type': 'user',
#  'uri': 'spotify:user:1275022654',
#  'followers': {'href': None, 'total': 56},
#  'country': 'US',
#  'product': 'premium',
#  'explicit_content': {'filter_enabled': False, 'filter_locked': False}}

# %%
username = user['display_name']
userlink = user['external_urls']['spotify']
userid = user['id']

print(f'We are generating a playlist for {username}, who can be found at {userlink}')
# Out:
# We are generating a playlist for Ananya Tinaikar, who can be found at https://open.spotify.com/user/1275022654

# %% [markdown]
# ### Functions to Flatten Response and Retrieve Genres

# %%
def get_attributes(row):
    
    release_dt = row['album'].get('release_date')
    
    artistinfo = []  
    
    for artist in row['album'].get('artists'):
        
        name = artist.get('name')
        id = artist.get('id')
        uri = artist.get('uri')
        
        artistinfo.append([name, id, uri])
    
    return [artistinfo, release_dt]
        

def top_track_response(response):

    if 'items' in response.keys():
        tracks = pd.DataFrame(response['items'])
    else:
        tracks = pd.DataFrame(response['tracks'])

    tracks['flat'] = tracks.apply(get_attributes,axis=1)


    return tracks

# %%
def get_artist_genres(artist_ids):  
    
    artists_info = pd.DataFrame()
    
    # Split artist IDs into batches of 50 (maximum allowed by Spotify API)
    batch_size = 50
    
    for i in range(0, len(artist_ids), batch_size):
        batch_ids = artist_ids[i:i + batch_size]
        response = sp.artists(batch_ids)['artists']
        response_df = pd.DataFrame(response)
        
        # Get artist information for the batch of IDs
        artists_info = pd.concat([artists_info,response_df])
        
            
    return artists_info

# %%
user_toptrack = sp.current_user_top_tracks(time_range='medium_term', limit=50)
your_tops = top_track_response(user_toptrack)

# %%
your_tops['artists_flat'] = your_tops['flat'].str[0]
your_tops['release_date'] = your_tops['flat'].str[1]

#your_tops = your_tops.set_index('id')
your_tops = your_tops.drop(columns=['flat'])
your_tops['artists_names'] = your_tops['artists_flat'].apply(lambda x: [artist[0] for artist in x])
your_tops['artists_ids'] = your_tops['artists_flat'].apply(lambda x: [artist[1] for artist in x])

# %%
your_tops = your_tops.explode(['artists_names','artists_ids'])
your_tops = your_tops.reset_index(drop=True)

# %%
#get_artist_genres(your_tops['artists_ids'].tolist())
artist_ids = your_tops['artists_ids'].tolist()
genres = get_artist_genres(artist_ids)

# %%
genres = genres[['id','genres']]
genres = genres.drop_duplicates(subset='id', keep='first')
genres = genres.reset_index(drop=True)

# %%
your_tops = pd.merge(your_tops, genres, left_on='artists_ids', right_on='id', how='outer')
your_tops = your_tops.drop(columns=['id_y']).rename(columns={'id_x':'id'})

# %%
your_tops
# Out:
#                                                 album  \
# 0   {'album_type': 'ALBUM', 'artists': [{'external...
# 1   {'album_type': 'SINGLE', 'artists': [{'externa...
# 2   {'album_type': 'SINGLE', 'artists': [{'externa...
# 3   {'album_type': 'ALBUM', 'artists': [{'external...
# 4   {'album_type': 'ALBUM', 'artists': [{'external...
# 5   {'album_type': 'ALBUM', 'artists': [{'external...
# 6   {'album_type': 'ALBUM', 'artists': [{'external...
# 7   {'album_type': 'ALBUM', 'artists': [{'external...
# 8   {'album_type': 'SINGLE', 'artists': [{'externa...
# 9   {'album_type': 'SINGLE', 'artists': [{'externa...
# 10  {'album_type': 'ALBUM', 'artists': [{'external...
# 11  {'album_type': 'ALBUM', 'artists': [{'external...
# 12  {'album_type': 'SINGLE', 'artists': [{'externa...
# 13  {'album_type': 'SINGLE', 'artists': [{'externa...
# 14  {'album_type': 'ALBUM', 'artists': [{'external...
# 15  {'album_type': 'ALBUM', 'artists': [{'external...
# 16  {'album_type': 'SINGLE', 'artists': [{'externa...
# 17  {'album_type': 'SINGLE', 'artists': [{'externa...
# 18  {'album_type': 'SINGLE', 'artists': [{'externa...
# 19  {'album_type': 'SINGLE', 'artists': [{'externa...
# 20  {'album_type': 'SINGLE', 'artists': [{'externa...
# 21  {'album_type': 'ALBUM', 'artists': [{'external...
# 22  {'album_type': 'ALBUM', 'artists': [{'external...
# 23  {'album_type': 'ALBUM', 'artists': [{'external...
# 24  {'album_type': 'ALBUM', 'artists': [{'external...
# 25  {'album_type': 'ALBUM', 'artists': [{'external...
# 26  {'album_type': 'SINGLE', 'artists': [{'externa...
# 27  {'album_type': 'ALBUM', 'artists': [{'external...
# 28  {'album_type': 'SINGLE', 'artists': [{'externa...
# 29  {'album_type': 'ALBUM', 'artists': [{'external...
# 30  {'album_type': 'ALBUM', 'artists': [{'external...
# 31  {'album_type': 'ALBUM', 'artists': [{'external...
# 32  {'album_type': 'EP', 'artists': [{'external_ur...
# 33  {'album_type': 'ALBUM', 'artists': [{'external...
# 34  {'album_type': 'SINGLE', 'artists': [{'externa...
# 35  {'album_type': 'SINGLE', 'artists': [{'externa...
# 36  {'album_type': 'ALBUM', 'artists': [{'external...
# 37  {'album_type': 'ALBUM', 'artists': [{'external...
# 38  {'album_type': 'ALBUM', 'artists': [{'external...
# 39  {'album_type': 'ALBUM', 'artists': [{'external...
# 40  {'album_type': 'ALBUM', 'artists': [{'external...
# 41  {'album_type': 'ALBUM', 'artists': [{'external...
# 42  {'album_type': 'ALBUM', 'artists': [{'external...
# 43  {'album_type': 'ALBUM', 'artists': [{'external...
# 44  {'album_type': 'ALBUM', 'artists': [{'external...
# 45  {'album_type': 'ALBUM', 'artists': [{'external...
# 46  {'album_type': 'EP', 'artists': [{'external_ur...
# 47  {'album_type': 'SINGLE', 'artists': [{'externa...
# 48  {'album_type': 'ALBUM', 'artists': [{'external...
# 49  {'album_type': 'SINGLE', 'artists': [{'externa...
# 50  {'album_type': 'ALBUM', 'artists': [{'external...
# 51  {'album_type': 'ALBUM', 'artists': [{'external...
# 52  {'album_type': 'SINGLE', 'artists': [{'externa...
# 53  {'album_type': 'SINGLE', 'artists': [{'externa...
# 54  {'album_type': 'SINGLE', 'artists': [{'externa...
# 55  {'album_type': 'SINGLE', 'artists': [{'externa...
# 56  {'album_type': 'ALBUM', 'artists': [{'external...
#
#                                               artists  \
# 0   [{'external_urls': {'spotify': 'https://open.s...
# 1   [{'external_urls': {'spotify': 'https://open.s...
# 2   [{'external_urls': {'spotify': 'https://open.s...
# 3   [{'external_urls': {'spotify': 'https://open.s...
# 4   [{'external_urls': {'spotify': 'https://open.s...
# 5   [{'external_urls': {'spotify': 'https://open.s...
# 6   [{'external_urls': {'spotify': 'https://open.s...
# 7   [{'external_urls': {'spotify': 'https://open.s...
# 8   [{'external_urls': {'spotify': 'https://open.s...
# 9   [{'external_urls': {'spotify': 'https://open.s...
# 10  [{'external_urls': {'spotify': 'https://open.s...
# 11  [{'external_urls': {'spotify': 'https://open.s...
# 12  [{'external_urls': {'spotify': 'https://open.s...
# 13  [{'external_urls': {'spotify': 'https://open.s...
# 14  [{'external_urls': {'spotify': 'https://open.s...
# 15  [{'external_urls': {'spotify': 'https://open.s...
# 16  [{'external_urls': {'spotify': 'https://open.s...
# 17  [{'external_urls': {'spotify': 'https://open.s...
# 18  [{'external_urls': {'spotify': 'https://open.s...
# 19  [{'external_urls': {'spotify': 'https://open.s...
# 20  [{'external_urls': {'spotify': 'https://open.s...
# 21  [{'external_urls': {'spotify': 'https://open.s...
# 22  [{'external_urls': {'spotify': 'https://open.s...
# 23  [{'external_urls': {'spotify': 'https://open.s...
# 24  [{'external_urls': {'spotify': 'https://open.s...
# 25  [{'external_urls': {'spotify': 'https://open.s...
# 26  [{'external_urls': {'spotify': 'https://open.s...
# 27  [{'external_urls': {'spotify': 'https://open.s...
# 28  [{'external_urls': {'spotify': 'https://open.s...
# 29  [{'external_urls': {'spotify': 'https://open.s...
# 30  [{'external_urls': {'spotify': 'https://open.s...
# 31  [{'external_urls': {'spotify': 'https://open.s...
# 32  [{'external_urls': {'spotify': 'https://open.s...
# 33  [{'external_urls': {'spotify': 'https://open.s...
# 34  [{'external_urls': {'spotify': 'https://open.s...
# 35  [{'external_urls': {'spotify': 'https://open.s...
# 36  [{'external_urls': {'spotify': 'https://open.s...
# 37  [{'external_urls': {'spotify': 'https://open.s...
# 38  [{'external_urls': {'spotify': 'https://open.s...
# 39  [{'external_urls': {'spotify': 'https://open.s...
# 40  [{'external_urls': {'spotify': 'https://open.s...
# 41  [{'external_urls': {'spotify': 'https://open.s...
# 42  [{'external_urls': {'spotify': 'https://open.s...
# 43  [{'external_urls': {'spotify': 'https://open.s...
# 44  [{'external_urls': {'spotify': 'https://open.s...
# 45  [{'external_urls': {'spotify': 'https://open.s...
# 46  [{'external_urls': {'spotify': 'https://open.s...
# 47  [{'external_urls': {'spotify': 'https://open.s...
# 48  [{'external_urls': {'spotify': 'https://open.s...
# 49  [{'external_urls': {'spotify': 'https://open.s...
# 50  [{'external_urls': {'spotify': 'https://open.s...
# 51  [{'external_urls': {'spotify': 'https://open.s...
# 52  [{'external_urls': {'spotify': 'https://open.s...
# 53  [{'external_urls': {'spotify': 'https://open.s...
# 54  [{'external_urls': {'spotify': 'https://open.s...
# 55  [{'external_urls': {'spotify': 'https://open.s...
# 56  [{'external_urls': {'spotify': 'https://open.s...
#
#                                     available_markets  disc_number  \
# 0   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 1   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 2   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 3   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 4   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 5   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 6   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 7   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 8   [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 9                                                  []            1
# 10  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 11  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 12  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 13  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 14  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 15  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 16  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 17  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 18  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 19  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 20  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 21  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 22  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 23  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 24  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 25  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 26  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 27  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 28  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 29  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 30  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 31  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 32  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 33  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 34  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 35  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 36  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 37  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 38  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 39  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 40  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 41  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 42  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 43  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 44  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 45  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 46  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 47  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 48  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 49                                       [CA, MX, US]            1
# 50  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 51  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 52  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 53  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 54  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 55  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 56  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
#
#     duration_ms  explicit              external_ids  \
# 0        186040      True  {'isrc': 'QZPEW2438198'}
# 1        213133     False  {'isrc': 'QZVEM2388797'}
# 2        157533      True  {'isrc': 'QZVEM2363057'}
# 3        180866     False  {'isrc': 'QZPEW2438200'}
# 4        236286     False  {'isrc': 'INS180808433'}
# 5        327508     False  {'isrc': 'GBAHS2400149'}
# 6        250291     False  {'isrc': 'GBAHS2100378'}
# 7        196071     False  {'isrc': 'GBAHS1901368'}
# 8        222784      True  {'isrc': 'GBAHS2301465'}
# 9        191889      True  {'isrc': 'FRDKW2203510'}
# 10       217200      True  {'isrc': 'USEE10301720'}
# 11       567106     False  {'isrc': 'GBAAP9500471'}
# 12       179133      True  {'isrc': 'USSM12208609'}
# 13       131872      True  {'isrc': 'USRC12301932'}
# 14       143940      True  {'isrc': 'USRC12302981'}
# 15       230013     False  {'isrc': 'GBAKW0100229'}
# 16       250934     False  {'isrc': 'USAT21811916'}
# 17       186365      True  {'isrc': 'USUM72404101'}
# 18       200000     False  {'isrc': 'TCACW1756799'}
# 19       169821     False  {'isrc': 'QM24S2308011'}
# 20       209698     False  {'isrc': 'QZHN32249247'}
# 21       171782      True  {'isrc': 'QZTB92360479'}
# 22       168000     False  {'isrc': 'TCAGF2219238'}
# 23       245560     False  {'isrc': 'GBWYK1800101'}
# 24       204933     False  {'isrc': 'FR9W11161077'}
# 25       228639     False  {'isrc': 'USUM72317276'}
# 26       235885      True  {'isrc': 'QZJG52400065'}
# 27       344692     False  {'isrc': 'USJ5G2020011'}
# 28       142514     False  {'isrc': 'QZJ842400387'}
# 29       323520     False  {'isrc': 'INS170600102'}
# 30       200373     False  {'isrc': 'INS182302348'}
# 31       173693     False  {'isrc': 'DEZ650900531'}
# 32       235766     False  {'isrc': 'GBCFB1900033'}
# 33       238805     False  {'isrc': 'GBUM72000433'}
# 34       165961     False  {'isrc': 'DEUM72307403'}
# 35       165961     False  {'isrc': 'DEUM72307403'}
# 36       243413     False  {'isrc': 'USQX91301564'}
# 37       216320      True  {'isrc': 'AUUM71500303'}
# 38       350160     False  {'isrc': 'GBSGZ0700023'}
# 39       350160     False  {'isrc': 'GBSGZ0700023'}
# 40       449160     False  {'isrc': 'GBAAP0001115'}
# 41       288647     False  {'isrc': 'INS180900091'}
# 42       168240     False  {'isrc': 'INS180900096'}
# 43       288647     False  {'isrc': 'INS180900091'}
# 44       168240     False  {'isrc': 'INS180900096'}
# 45       234173      True  {'isrc': 'USUM70722797'}
# 46       333181     False  {'isrc': 'INY090800026'}
# 47       258472     False  {'isrc': 'INY092200126'}
# 48       382973     False  {'isrc': 'INS170600224'}
# 49       299360     False  {'isrc': 'GBK3W1000390'}
# 50       192213     False  {'isrc': 'SEPQA0450060'}
# 51       179761      True  {'isrc': 'USUM71909852'}
# 52       165263     False  {'isrc': 'DES232200260'}
# 53       165263     False  {'isrc': 'DES232200260'}
# 54       165263     False  {'isrc': 'DES232200260'}
# 55       222784      True  {'isrc': 'GBAHS2301465'}
# 56       159245     False  {'isrc': 'GBKPL2205058'}
#
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/track/5E...
# 1   {'spotify': 'https://open.spotify.com/track/6O...
# 2   {'spotify': 'https://open.spotify.com/track/2k...
# 3   {'spotify': 'https://open.spotify.com/track/18...
# 4   {'spotify': 'https://open.spotify.com/track/0E...
# 5   {'spotify': 'https://open.spotify.com/track/39...
# 6   {'spotify': 'https://open.spotify.com/track/1u...
# 7   {'spotify': 'https://open.spotify.com/track/6A...
# 8   {'spotify': 'https://open.spotify.com/track/1M...
# 9   {'spotify': 'https://open.spotify.com/track/6F...
# 10  {'spotify': 'https://open.spotify.com/track/1M...
# 11  {'spotify': 'https://open.spotify.com/track/5x...
# 12  {'spotify': 'https://open.spotify.com/track/1S...
# 13  {'spotify': 'https://open.spotify.com/track/3r...
# 14  {'spotify': 'https://open.spotify.com/track/51...
# 15  {'spotify': 'https://open.spotify.com/track/4t...
# 16  {'spotify': 'https://open.spotify.com/track/5i...
# 17  {'spotify': 'https://open.spotify.com/track/5N...
# 18  {'spotify': 'https://open.spotify.com/track/0m...
# 19  {'spotify': 'https://open.spotify.com/track/5w...
# 20  {'spotify': 'https://open.spotify.com/track/58...
# 21  {'spotify': 'https://open.spotify.com/track/2u...
# 22  {'spotify': 'https://open.spotify.com/track/0l...
# 23  {'spotify': 'https://open.spotify.com/track/2L...
# 24  {'spotify': 'https://open.spotify.com/track/5p...
# 25  {'spotify': 'https://open.spotify.com/track/51...
# 26  {'spotify': 'https://open.spotify.com/track/17...
# 27  {'spotify': 'https://open.spotify.com/track/0p...
# 28  {'spotify': 'https://open.spotify.com/track/2G...
# 29  {'spotify': 'https://open.spotify.com/track/2i...
# 30  {'spotify': 'https://open.spotify.com/track/3x...
# 31  {'spotify': 'https://open.spotify.com/track/5b...
# 32  {'spotify': 'https://open.spotify.com/track/0N...
# 33  {'spotify': 'https://open.spotify.com/track/3U...
# 34  {'spotify': 'https://open.spotify.com/track/5s...
# 35  {'spotify': 'https://open.spotify.com/track/5s...
# 36  {'spotify': 'https://open.spotify.com/track/7y...
# 37  {'spotify': 'https://open.spotify.com/track/6K...
# 38  {'spotify': 'https://open.spotify.com/track/2S...
# 39  {'spotify': 'https://open.spotify.com/track/2S...
# 40  {'spotify': 'https://open.spotify.com/track/6h...
# 41  {'spotify': 'https://open.spotify.com/track/5i...
# 42  {'spotify': 'https://open.spotify.com/track/15...
# 43  {'spotify': 'https://open.spotify.com/track/5i...
# 44  {'spotify': 'https://open.spotify.com/track/15...
# 45  {'spotify': 'https://open.spotify.com/track/7i...
# 46  {'spotify': 'https://open.spotify.com/track/0g...
# 47  {'spotify': 'https://open.spotify.com/track/0C...
# 48  {'spotify': 'https://open.spotify.com/track/4B...
# 49  {'spotify': 'https://open.spotify.com/track/6R...
# 50  {'spotify': 'https://open.spotify.com/track/3l...
# 51  {'spotify': 'https://open.spotify.com/track/6C...
# 52  {'spotify': 'https://open.spotify.com/track/75...
# 53  {'spotify': 'https://open.spotify.com/track/75...
# 54  {'spotify': 'https://open.spotify.com/track/75...
# 55  {'spotify': 'https://open.spotify.com/track/1M...
# 56  {'spotify': 'https://open.spotify.com/track/3q...
#
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/tracks/5EpQ3S8Lvqz4...  5EpQ3S8Lvqz4juCGv4NXX8
# 1   https://api.spotify.com/v1/tracks/6OvLJA8LYyDN...  6OvLJA8LYyDNtm9vrBWGEY
# 2   https://api.spotify.com/v1/tracks/2kWa0CB8BPIp...  2kWa0CB8BPIptCR53wRJTN
# 7                         [edm, house, stutter house]
# 8                         [edm, house, stutter house]
# 9                                                  []
# 10  [dance pop, hip hop, hip pop, neo soul, pop ra...
# 11  [big beat, breakbeat, electronica, intelligent...
# 12                           [bedroom pop, indie pop]
# 13                                              [pop]
# 14                                              [pop]
# 15                 [dance pop, europop, new wave pop]
# 16     [alternative dance, indie poptimism, nu disco]
# 17                                              [pop]
# 18                                      [escape room]
# 19  [electropop, indie electropop, indie pop rap, ...
# 20                            [singer-songwriter pop]
# 21                                                 []
# 22                                         [rap rock]
# 23           [bhangra, classic bhangra, desi hip hop]
# 24            [french indie pop, french indietronica]
# 25                                              [pop]
# 26                                                 []
# 27                  [indie pop, la indie, pov: indie]
# 28                                                 []
# 29                                                 []
# 30               [desi hip hop, filmi, tamil hip hop]
# 31             [brass band, second line, street band]
# 32                     [chillwave, edm, indietronica]
# 33  [gauze pop, indietronica, modern rock, pov: in...
# 34                                    [stutter house]
# 35                                                 []
# 36                                          [bow pop]
# 37  [australian psych, modern rock, neo-psychedeli...
# 38                          [filmi, modern bollywood]
# 39                         [classic bollywood, filmi]
# 40  [alternative rock, dance rock, madchester, new...
# 41                                            [filmi]
# 42                                            [filmi]
# 43                                                 []
# 44                                                 []
# 45              [escape room, indietronica, new rave]
# 46                          [filmi, modern bollywood]
# 47                          [filmi, modern bollywood]
# 48                          [filmi, modern bollywood]
# 49  [indie pop, indietronica, modern dream pop, po...
# 50                                      [persian pop]
# 51                            [ohio hip hop, pop rap]
# 52                                                 []
# 53                                                 []
# 54                                         [bassline]
# 55                                     [hip hop, rap]
# 56                      [pov: indie, psychedelic pop]
#
# [57 rows x 22 columns]

# %% [markdown]
# ### Top 10 Songs from Each Artist in Our Top 50

# %%
# batch_size = 50
artist_toptracks = pd.DataFrame()

for i in range(0, len(your_tops['artists_ids'])):
    
    toptracks = sp.artist_top_tracks(your_tops['artists_ids'][i])
    toptracks = top_track_response(toptracks).reset_index(drop=True)
    artist_toptracks = pd.concat([artist_toptracks,toptracks],axis=0)
    
artist_toptracks = artist_toptracks.reset_index(drop=True)

# %%
artist_toptracks['artists_flat'] = artist_toptracks['flat'].str[0]
artist_toptracks['release_date'] = artist_toptracks['flat'].str[1]

# %%
artist_toptracks = artist_toptracks.drop(columns=['flat'])
artist_toptracks['artists_names'] = artist_toptracks['artists_flat'].apply(lambda x: [artist[0] for artist in x])
artist_toptracks['artists_ids'] = artist_toptracks['artists_flat'].apply(lambda x: [artist[1] for artist in x])

# %%
artist_toptracks = artist_toptracks.explode(['artists_names','artists_ids'])
artist_toptracks = artist_toptracks.reset_index(drop=True)

# %%
artist_tops_ids = artist_toptracks['artists_ids'].tolist()
genres = get_artist_genres(artist_tops_ids)
genres = genres[['id','genres']]
genres = genres.drop_duplicates(subset='id', keep='first')

# %%
artist_toptracks = artist_toptracks.merge(genres, left_on='artists_ids',right_on='id',how='outer')
artist_toptracks = artist_toptracks.drop(columns=['id_y']).rename(columns={'id_x':'id'}).reset_index(drop=True)

# %%
#Final Universe of Tracks to Generate Playlist From
playlist_universe = pd.concat([your_tops,artist_toptracks],ignore_index=True)
playlist_universe
# Out:
#                                                  album  \
# 0    {'album_type': 'ALBUM', 'artists': [{'external...
# 1    {'album_type': 'SINGLE', 'artists': [{'externa...
# 2    {'album_type': 'SINGLE', 'artists': [{'externa...
# 3    {'album_type': 'ALBUM', 'artists': [{'external...
# 4    {'album_type': 'ALBUM', 'artists': [{'external...
# ..                                                 ...
# 728  {'album_type': 'album', 'artists': [{'external...
# 729  {'album_type': 'album', 'artists': [{'external...
# 730  {'album_type': 'album', 'artists': [{'external...
# 731  {'album_type': 'album', 'artists': [{'external...
# 732  {'album_type': 'album', 'artists': [{'external...
#
#                                                artists  \
# 0    [{'external_urls': {'spotify': 'https://open.s...
# 1    [{'external_urls': {'spotify': 'https://open.s...
# 2    [{'external_urls': {'spotify': 'https://open.s...
# 3    [{'external_urls': {'spotify': 'https://open.s...
# 4    [{'external_urls': {'spotify': 'https://open.s...
# ..                                                 ...
# 728  [{'external_urls': {'spotify': 'https://open.s...
# 729  [{'external_urls': {'spotify': 'https://open.s...
# 730  [{'external_urls': {'spotify': 'https://open.s...
# 731  [{'external_urls': {'spotify': 'https://open.s...
# 732  [{'external_urls': {'spotify': 'https://open.s...
#
#                                      available_markets  disc_number  \
# 0    [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 1    [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 2    [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 3    [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 4    [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# ..                                                 ...          ...
# 728                                                NaN            1
# 729                                                NaN            1
# 730                                                NaN            1
# 731                                                NaN            1
# 732                                                NaN            1
#
#      duration_ms  explicit              external_ids  \
# 0         186040      True  {'isrc': 'QZPEW2438198'}
# 1         213133     False  {'isrc': 'QZVEM2388797'}
# 2         157533      True  {'isrc': 'QZVEM2363057'}
# 3         180866     False  {'isrc': 'QZPEW2438200'}
# 4         236286     False  {'isrc': 'INS180808433'}
# ..           ...       ...                       ...
# 728       128438     False  {'isrc': 'GBKPL2205059'}
# 729       184314     False  {'isrc': 'GBKPL2205063'}
# 730       114742     False  {'isrc': 'GBKPL2205056'}
# 731       299546     False  {'isrc': 'GBKPL1963384'}
# 732       110820     False  {'isrc': 'GBKPL2205064'}
#
#                                          external_urls  \
# 0    {'spotify': 'https://open.spotify.com/track/5E...
# 1    {'spotify': 'https://open.spotify.com/track/6O...
# 2    {'spotify': 'https://open.spotify.com/track/2k...
# 3    {'spotify': 'https://open.spotify.com/track/18...
# 4    {'spotify': 'https://open.spotify.com/track/0E...
# ..                                                 ...
# 728  {'spotify': 'https://open.spotify.com/track/7K...
# 729  {'spotify': 'https://open.spotify.com/track/6T...
# 730  {'spotify': 'https://open.spotify.com/track/56...
# 731  {'spotify': 'https://open.spotify.com/track/3H...
# 732  {'spotify': 'https://open.spotify.com/track/4z...
#
#                                                   href  \
# 0    https://api.spotify.com/v1/tracks/5EpQ3S8Lvqz4...
# 1    https://api.spotify.com/v1/tracks/6OvLJA8LYyDN...
# 2    https://api.spotify.com/v1/tracks/2kWa0CB8BPIp...
# 3    https://api.spotify.com/v1/tracks/18klQHQroXxx...
# 4    https://api.spotify.com/v1/tracks/0ErXZ1NMqOEF...
# ..                                                 ...
# 728  https://api.spotify.com/v1/tracks/7KnGAY27aFqg...
# 729  https://api.spotify.com/v1/tracks/6TorufIR9E06...
# 730  https://api.spotify.com/v1/tracks/56sDw3DIGcUS...
# 731  https://api.spotify.com/v1/tracks/3HAYmp6l5lYG...
# 732  https://api.spotify.com/v1/tracks/4zzwmX1ntxHB...
#
#                          id  ...  \
# 0    5EpQ3S8Lvqz4juCGv4NXX8  ...
# 1    6OvLJA8LYyDNtm9vrBWGEY  ...
# 2    2kWa0CB8BPIptCR53wRJTN  ...
# 3    18klQHQroXxxtAMZRlALUL  ...
# 4    0ErXZ1NMqOEFGJPQvU9OKF  ...
# ..                      ...  ...
# 728  7KnGAY27aFqgiYySwt7yg5  ...
# 729  6TorufIR9E06RXo3VhZaae  ...
# 730  56sDw3DIGcUStBO5SguYPK  ...
# 731  3HAYmp6l5lYGG8zz4qMbIX  ...
# 732  4zzwmX1ntxHBaFWJahkVTx  ...
#
#                                            preview_url track_number   type  \
# 0    https://p.scdn.co/mp3-preview/9565dfbfc8394831...            1  track
# 1    https://p.scdn.co/mp3-preview/85ea92ee576b3a2c...            1  track
# 2    https://p.scdn.co/mp3-preview/2b5f34dd633bf712...            2  track
# 3    https://p.scdn.co/mp3-preview/c81851624ab1d8e3...            4  track
# 4    https://p.scdn.co/mp3-preview/3db023c99eb78c8e...            2  track
# ..                                                 ...          ...    ...
# 728  https://p.scdn.co/mp3-preview/ede56dcbbfdd73bf...            7  track
# 729  https://p.scdn.co/mp3-preview/a50c71ae801b7b7a...           12  track
# 730  https://p.scdn.co/mp3-preview/8964252d2ba64d1b...            4  track
# 731  https://p.scdn.co/mp3-preview/bfd08651cbfbd8d0...            2  track
# 732  https://p.scdn.co/mp3-preview/04226173146f81e3...           13  track
#
#                                       uri  \
# 0    spotify:track:5EpQ3S8Lvqz4juCGv4NXX8
# 1    spotify:track:6OvLJA8LYyDNtm9vrBWGEY
# 2    spotify:track:2kWa0CB8BPIptCR53wRJTN
# 3    spotify:track:18klQHQroXxxtAMZRlALUL
# 4    spotify:track:0ErXZ1NMqOEFGJPQvU9OKF
# ..                                    ...
# 728  spotify:track:7KnGAY27aFqgiYySwt7yg5
# 729  spotify:track:6TorufIR9E06RXo3VhZaae
# 730  spotify:track:56sDw3DIGcUStBO5SguYPK
# 731  spotify:track:3HAYmp6l5lYGG8zz4qMbIX
# 732  spotify:track:4zzwmX1ntxHBaFWJahkVTx
#
#                                           artists_flat release_date  \
# 0    [[Myles Cameron, 2B2dZ6tZkA7MAHcPaHw1wF, spoti...   2024-05-07
# 1    [[Myles Cameron, 2B2dZ6tZkA7MAHcPaHw1wF, spoti...   2024-01-30
# 2    [[Myles Cameron, 2B2dZ6tZkA7MAHcPaHw1wF, spoti...   2024-01-30
# 3    [[Myles Cameron, 2B2dZ6tZkA7MAHcPaHw1wF, spoti...   2024-05-07
# 4    [[Salim–Sulaiman, 6ohaQzKaXrobAL8paLSaxq, spot...   2008-09-19
# ..                                                 ...          ...
# 728  [[Djo, 5p9HO3XC5P3BLxJs5Mtrhm, spotify:artist:...   2022-09-16
# 729  [[Djo, 5p9HO3XC5P3BLxJs5Mtrhm, spotify:artist:...   2022-09-16
# 730  [[Djo, 5p9HO3XC5P3BLxJs5Mtrhm, spotify:artist:...   2022-09-16
# 731  [[Djo, 5p9HO3XC5P3BLxJs5Mtrhm, spotify:artist:...   2019-09-13
# 732  [[Djo, 5p9HO3XC5P3BLxJs5Mtrhm, spotify:artist:...   2022-09-16
#
#       artists_names             artists_ids  \
# 0     Myles Cameron  2B2dZ6tZkA7MAHcPaHw1wF
# 1     Myles Cameron  2B2dZ6tZkA7MAHcPaHw1wF
# 2     Myles Cameron  2B2dZ6tZkA7MAHcPaHw1wF
# 3     Myles Cameron  2B2dZ6tZkA7MAHcPaHw1wF
# 4    Salim–Sulaiman  6ohaQzKaXrobAL8paLSaxq
# ..              ...                     ...
# 728             Djo  5p9HO3XC5P3BLxJs5Mtrhm
# 729             Djo  5p9HO3XC5P3BLxJs5Mtrhm
# 730             Djo  5p9HO3XC5P3BLxJs5Mtrhm
# 731             Djo  5p9HO3XC5P3BLxJs5Mtrhm
# 732             Djo  5p9HO3XC5P3BLxJs5Mtrhm
#
#                                      genres is_playable
# 0                               [chill r&b]         NaN
# 1                               [chill r&b]         NaN
# 2                               [chill r&b]         NaN
# 3                               [chill r&b]         NaN
# 4    [filmi, indian folk, modern bollywood]         NaN
# ..                                      ...         ...
# 728           [pov: indie, psychedelic pop]        True
# 729           [pov: indie, psychedelic pop]        True
# 730           [pov: indie, psychedelic pop]        True
# 731           [pov: indie, psychedelic pop]        True
# 732           [pov: indie, psychedelic pop]        True
#
# [733 rows x 23 columns]

# %%
# # Define aggregation functions
# def unique_names(x):
#     unique_names_set = set(x)
#     return ', '.join(unique_names_set)

aggregations = {
    #'id': lambda x: ', '.join(set(', '.join(x).split(', '))),
    'artists_ids': lambda x: ', '.join(x),
    'genres': 'sum',
    'artists_names': lambda x: ', '.join(map(str, pd.Series(x).drop_duplicates()))
}

unique_universe = playlist_universe.groupby('id').agg(aggregations).reset_index()

# %%
unique_universe
# Out:
#                          id  \
# 0    022ps5TymdGgPGus4ojM4u
# 1    02rdXe0KhMe8p6ZHzYtuw0
# 2    04mAOoQNsXmDJlyupJwmkO
# 3    05jEfIK1V6ELyqz87oUUnN
# 4    084ERnS6WhLay9MrRLo7Hw
# ..                      ...
# 465  7uA5gUTAB85bUXDBLb1LBy
# 466  7wZZoaI2AykMAL4nyYMKv3
# 467  7xi6IzpwkgtpenLzl5LMLc
# 468  7xoUc6faLbCqZO6fQEYprd
# 469  7yWWGHEE0BHHcQYl4JPRtJ
#
#                                            artists_ids  \
# 0                               7Ez6lTtSMjMf2YSYpukP1I
# 1                               5SXuuuRpukkTvsLuUknva1
# 2                               0LyfQWJT6nXafLPZqxe9Of
# 3                               3oTDO2HdnIHS42f8E6KIFJ
# 4    2B2dZ6tZkA7MAHcPaHw1wF, 2B2dZ6tZkA7MAHcPaHw1wF...
# ..                                                 ...
# 465     3csPCeXsj2wezyvkRFzvmV, 0sElgscu7tp38PM1MtsUz7
# 466                             0jW6R8CVyVohuUJVcuweDI
# 467                             0QJIPDAEDILuo8AIq3pMuU
# 468                             66CXWjxzNUsdJxJ2JdwvnR
# 469                             0jW6R8CVyVohuUJVcuweDI
#
#                                                 genres       artists_names
# 0                                                   []               Dasha
# 1                                       [hip hop, rap]           Baby Keem
# 2                                                   []     Various Artists
# 3                                                   []         DJ Max Star
# 4         [chill r&b, chill r&b, chill r&b, chill r&b]       Myles Cameron
# ..                                                 ...                 ...
# 465  [big beat, breakbeat, electronica, intelligent...  Orbital, Energy 52
# 466                                          [bow pop]      The Piano Guys
# 467              [escape room, indietronica, new rave]              M.I.A.
# 468                                              [pop]       Ariana Grande
# 469                                          [bow pop]      The Piano Guys
#
# [470 rows x 4 columns]

# %% [markdown]
# ## Retrieve Audio Features for Tracks in our Universe

# %% [markdown]
# Now that we have our playlist universe, we get "audio features" for each of our tracks. Audio features we are interested in include:
# <ol>
#     <li>Danceability - Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. </li>
#     <li>Energy - Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity.</li>
#     <li>Valence - How positive the song sounds</li>
# </ol>

# %%
def get_audio_features(track_ids):
 
    dance, energy, valence = [], [], []
    
    batch_size = 100
    
    for i in range(0,len(track_ids),batch_size):
        
        batch_ids = list(track_ids[i:i+batch_size])
        aud_feat = sp.audio_features(batch_ids)
        
        for feat in aud_feat:
            if feat is not None:
                dance.append(feat['danceability'])
                energy.append(feat['energy'])
                valence.append(feat['danceability'])
            else:
                dance.append(0)
                energy.append(0)
                valence.append(0)
    
    print('Done!')
    return dance, energy, valence

# %%
tracks = list(unique_universe['id'])

unique_universe['danceability'], unique_universe['energy'], unique_universe['valence'] = get_audio_features(tracks)
# Out:
# Done!

# %% [markdown]
# ## Filtering Playlist

# %% [markdown]
# Next we will define a function to filter the playlist based on user-specified inputs for three questions (each corresponding to a particular audio feature)

# %%
#Function to Filter Playlist based on Selections
def filter_playlist(df,valence,dance,activity):
    
    mapping = {} 
    
    if valence:
        mapping = {
            'Bad': (0.0,0.4999),
            'Good': (0.5,1.0)
        }
        val_min, val_max = mapping.get(valence, (0.0,1.0))
        
    if dance:
        mapping = {
             1: (0.0, 0.2),
             2: (0.2, 0.4),
             3: (0.4, 0.6),
             4: (0.6, 0.8),
             5: (0.8, 1.0)
        } 
        dance_min, dance_max = mapping.get(dance, (0.0,1.0))
    
    if activity:
        mapping = {
             'Solo Chill': (0.0, 0.2),
             'Chill with Friends': (0.2, 0.4),
             'Social Gathering': (0.4, 0.6),
             'Party': (0.6, 0.8),
             'Rager': (0.8, 1.0)
        } 
        act_min, act_max = mapping.get(activity, (0.0,1.0))
    
    
    df = df[(df['valence'] > val_min) & (df['valence'] < val_max)]
    df = df[(df['danceability'] > dance_min) & (df['danceability'] < dance_max)]
    df = df[(df['energy'] > act_min) & (df['energy'] < act_max)]
    df = df.reset_index(drop=True)

    return df

# %%
val_value = input('What mood are you in? ')
dan_value = input('How much do you want to dance? ')
act_value = input('What activity are you doing? ')
# Out:
# What mood are you in? Good
# How much do you want to dance? 5
# What activity are you doing? Rager

# %%
result_playlist = filter_playlist(unique_universe,val_value,dan_value,act_value)
result_playlist
# Out:
#                          id                                     artists_ids  \
# 0    0HMqknanFIn0efQ5U4nUHT                          74D1UgRzMhTSPz698exXmR
# 1    0M9E0hfrH44KPVX6AJoVnn                          7hQmAXAzWI6D350VTgkKTG
# 2    0UaMYEvWZi0ZqiDOoHU3YI                          2wIVse2owClT7go1WT98tk
# 3    0bHnzW0bxdghfzdX0BhDht                          1JdHoZwkwOmX2Pl2iTwnzc
# 4    0cVeP9t3QChKYHKNGWfPnD                          0QJIPDAEDILuo8AIq3pMuU
# ..                      ...                                             ...
# 109  7lPYsLXUUZMhWACOLi9U86  61pcWUzNqpHNWc21SuHP1J, 75xNYf2GU5wtQqBrd74SlY
# 110  7rCrOTI49IE199dlDkGcC5                          1q4618qKswelCGLoanFKQh
# 111  7skteOnDbwZ3ZvjSe99xv2                          0PCCGZ0wGLizHt2KZ7hhA2
# 112  7uA5gUTAB85bUXDBLb1LBy  3csPCeXsj2wezyvkRFzvmV, 0sElgscu7tp38PM1MtsUz7
# 113  7xi6IzpwkgtpenLzl5LMLc                          0QJIPDAEDILuo8AIq3pMuU
#
#                                                 genres         artists_names  \
# 0             [bhangra, classic bhangra, desi hip hop]            Panjabi MC
# 1                                        [persian pop]                 Arash
# 2    [dance pop, hip hop, hip pop, neo soul, pop ra...         Missy Elliott
# 3                            [filmi, modern bollywood]       Vishal Bhardwaj
# 4                [escape room, indietronica, new rave]                M.I.A.
# ..                                                 ...                   ...
# 109           [escape room, brisbane indie, dark trap]  The Buttress, Zheani
# 110                                         [rap rock]   Joey Valence & Brae
# 111                                                 []               Artemas
# 112  [big beat, breakbeat, electronica, intelligent...    Orbital, Energy 52
# 113              [escape room, indietronica, new rave]                M.I.A.
#
#      danceability  energy  valence
# 0           0.719   0.806    0.719
# 1           0.708   0.904    0.708
# 2           0.904   0.813    0.904
# 3           0.817   0.922    0.817
# 4           0.582   0.844    0.582
# ..            ...     ...      ...
# 109         0.504   0.944    0.504
# 110         0.808   0.987    0.808
# 111         0.656   0.876    0.656
# 112         0.606   0.933    0.606
# 113         0.764   0.916    0.764
#
# [114 rows x 7 columns]

# %% [markdown]
# ## Logic to Ensure 15 songs per Playlist

# %% [markdown]
# We are defining a good playlist as one that has 15 songs. However, there are cases where filtering parameters may result in a final universe that is < 15 songs. We will define methodology to address such cases.

# %%
flat_genres = []

for sublist in result_playlist['genres']:
    flat_genres.extend(sublist)

flat_genres = list(set(flat_genres))
flat_genres
# Out:
# ['neo-psychedelic',
#  'europop',
#  'belgian dance',
#  'brass band',
#  'canadian pop',
#  'madchester',
#  'electro',
#  'second line',
#  'pop rap',
#  'german techno',
#  'indietronica',
#  'nu disco',
#  'australian dance',
#  'virginia hip hop',
#  'trance',
#  'dance rock',
#  'brisbane indie',
#  'big beat',
#  'pop',
#  'german hip hop',
#  'new romantic',
#  'alternative hip hop',
#  'filmi',
#  'new rave',
#  'german trance',
#  'permanent wave',
#  'complextro',
#  'rap',
#  'desi hip hop',
#  'escape room',
#  'new wave pop',
#  'house',
#  'hip pop',
#  'electropop',
#  'indie pop rap',
#  'aussietronica',
#  'australian electropop',
#  'indie electropop',
#  'indie soul',
#  'alternative r&b',
#  'edm',
#  'desi pop',
#  'tamil hip hop',
#  'modern rock',
#  'rock',
#  'pop edm',
#  'classic bollywood',
#  'bubble trance',
#  'new wave',
#  'australian psych',
#  'progressive house',
#  'neo soul',
#  'rap rock',
#  'bhangra',
#  'vapor soul',
#  'breakbeat',
#  'alabama rap',
#  'r&b',
#  'alternative dance',
#  'experimental r&b',
#  'pov: indie',
#  'big room',
#  'post-punk',
#  'brazilian edm',
#  'chillwave',
#  'ohio hip hop',
#  'hip hop',
#  'brostep',
#  'electronica',
#  'german dance',
#  'modern bollywood',
#  'persian pop',
#  'dance pop',
#  'modern dream pop',
#  'uk post-punk',
#  'canadian contemporary r&b',
#  'pop dance',
#  'norwegian indie',
#  'street band',
#  'synthpop',
#  'singer-songwriter pop',
#  'classic bhangra',
#  'stutter house',
#  'bedroom pop',
#  'alternative rock',
#  'dutch trance',
#  'intelligent dance music',
#  'rave',
#  'indie pop',
#  'indie poptimism',
#  'bassline',
#  'neo-singer-songwriter',
#  'dark trap',
#  'urban contemporary']

# %%
#Define Function to Ensure 15 song Playlist
def fifteen_songs(unique_universe,result_playlist):
    #Retrieving list of current unique genres in dataset
    flat_genres = []

    for sublist in result_playlist['genres']:
        flat_genres.extend(sublist)

    flat_genres = list(set(flat_genres)) #Storing as variable
    
    r_index = 0 #row index
    l_index = 0 #
    filter_genre = flat_genres[l_index] #current genre we are filtering for
    uni_parsed = len(unique_universe)#number of rows to parse through

    #Checking if we've parsed through all rows yet 
    while uni_parsed >= 0:
        for genres in unique_universe['genres']:
            uni_parsed -= 1
            r_index += 1
            for item in genres:
                if item==filter_genre:
                    row = pd.DataFrame(unique_universe.iloc[r_index]).transpose()
                    result_playlist = pd.concat([result_playlist,row],ignore_index=True)
                    break
            #Checking length of result playlist/uni parsed
            if len(result_playlist) >= 15:
                uni_parsed = -1
                break
        break

    return result_playlist

# %%
result = fifteen_songs(unique_universe,result_playlist)
result
# Out:
#                          id                                     artists_ids  \
# 0    0HMqknanFIn0efQ5U4nUHT                          74D1UgRzMhTSPz698exXmR
# 1    0M9E0hfrH44KPVX6AJoVnn                          7hQmAXAzWI6D350VTgkKTG
# 2    0UaMYEvWZi0ZqiDOoHU3YI                          2wIVse2owClT7go1WT98tk
# 3    0bHnzW0bxdghfzdX0BhDht                          1JdHoZwkwOmX2Pl2iTwnzc
# 4    0cVeP9t3QChKYHKNGWfPnD                          0QJIPDAEDILuo8AIq3pMuU
# ..                      ...                                             ...
# 109  7lPYsLXUUZMhWACOLi9U86  61pcWUzNqpHNWc21SuHP1J, 75xNYf2GU5wtQqBrd74SlY
# 110  7rCrOTI49IE199dlDkGcC5                          1q4618qKswelCGLoanFKQh
# 111  7skteOnDbwZ3ZvjSe99xv2                          0PCCGZ0wGLizHt2KZ7hhA2
# 112  7uA5gUTAB85bUXDBLb1LBy  3csPCeXsj2wezyvkRFzvmV, 0sElgscu7tp38PM1MtsUz7
# 113  7xi6IzpwkgtpenLzl5LMLc                          0QJIPDAEDILuo8AIq3pMuU
#
#                                                 genres         artists_names  \
# 0             [bhangra, classic bhangra, desi hip hop]            Panjabi MC
# 1                                        [persian pop]                 Arash
# 2    [dance pop, hip hop, hip pop, neo soul, pop ra...         Missy Elliott
# 3                            [filmi, modern bollywood]       Vishal Bhardwaj
# 4                [escape room, indietronica, new rave]                M.I.A.
# ..                                                 ...                   ...
# 109           [escape room, brisbane indie, dark trap]  The Buttress, Zheani
# 110                                         [rap rock]   Joey Valence & Brae
# 111                                                 []               Artemas
# 112  [big beat, breakbeat, electronica, intelligent...    Orbital, Energy 52
# 113              [escape room, indietronica, new rave]                M.I.A.
#
#      danceability  energy  valence
# 0           0.719   0.806    0.719
# 1           0.708   0.904    0.708
# 2           0.904   0.813    0.904
# 3           0.817   0.922    0.817
# 4           0.582   0.844    0.582
# ..            ...     ...      ...
# 109         0.504   0.944    0.504
# 110         0.808   0.987    0.808
# 111         0.656   0.876    0.656
# 112         0.606   0.933    0.606
# 113         0.764   0.916    0.764
#
# [114 rows x 7 columns]

# %% [markdown]
# ## Map the Song IDs to their Names

# %%
song_name_map = playlist_universe[['id','name']].drop_duplicates()
song_name_map
# Out:
#                          id               name
# 0    5EpQ3S8Lvqz4juCGv4NXX8            Boyhood
# 1    6OvLJA8LYyDNtm9vrBWGEY             Luh Ya
# 2    2kWa0CB8BPIptCR53wRJTN            Softboy
# 3    18klQHQroXxxtAMZRlALUL            Sundown
# 4    0ErXZ1NMqOEFGJPQvU9OKF         Mar Jawaan
# ..                      ...                ...
# 728  7KnGAY27aFqgiYySwt7yg5  I Want Your Video
# 729  6TorufIR9E06RXo3VhZaae     Figure You Out
# 730  56sDw3DIGcUStBO5SguYPK               Fool
# 731  3HAYmp6l5lYGG8zz4qMbIX      Personal Lies
# 732  4zzwmX1ntxHBaFWJahkVTx            Slither
#
# [470 rows x 2 columns]

# %%
result = result.merge(song_name_map, on='id',how='inner')

# %%
#Spotify has a limit of # of songs that can be written to a playlsit
if len(result) > 100:
    result = result[0:100]

# %% [markdown]
# ## Create Playlist via API

# %%
songs = list(result['id'])

# %%
def write_playlist(dataframe):
    songs = list(dataframe['id'])
    
    playlist = sp.user_playlist_create(user=userid, name='By Pyotr',public=False)
    playlist = sp.playlist_add_items(playlist_id=playlist['id'], items=songs)
    
    if playlist:
        print("Pyotr has written your playlist to your account. Do svidaniya")

# %%
write_playlist(result)
# Out:
# Pyotr has written your playlist to your account. Do svidaniya

# %%
import sys
print(sys.executable)
# Out:
# C:\Anaconda\python.exe
